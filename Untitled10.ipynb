# %% [markdown]
# <a href="https://colab.research.google.com/github/maliksahb05555-oss/Data-base/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#log in system with nested loops
print("set username and pass\n")
u = ("Ali Hassan")
p = ("4321")
print("\nNow, please log in.\n")
for attempt in range(5):
    u1 = ("Ali Hassan")
    p1 = ("4321")
    if u1 == u:
        if p1 == p:
            print("Login successful")
            break
        else:
            print("wrong password " , attempt + 1 , " attempt")
    else:
        print("wrong username " , attempt + 1 , " attempt\n")
else:
     print("you have used wrong credentials 5 times")

print("program is ended")
# Out:
# set username and pass
#
#
# Now, please log in.
#
# Login successful
# program is ended

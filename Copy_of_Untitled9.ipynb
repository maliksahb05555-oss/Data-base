# %% [markdown]
# <a href="https://colab.research.google.com/github/maliksahb05555-oss/Data-base/blob/main/Copy_of_Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if Else login system with User Define/set password

print("Please Set your username and password")
print("\n")

N = input("Enter your name: ")
P = input("Set your password: ")


print("\n")

print("Please use your username and password to login\n")

username = input("Username: ")
password = input("Password: ")

if username == N:
    if password == P:
        print("Login Successful")
    else:
        print("Incorrect Password")

else:
    print("Please try again")

# %% [markdown]
# <a href="https://colab.research.google.com/github/maliksahb05555-oss/Data-base/blob/main/Another_copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name={1:"abass",2:"danish",3:"Ali",4:"Usman"}
Marks={"ABass":44,"Danish":50,"ali":28,"usman":34}
print(Name[3])
print(Marks["ali"])
print(type(Marks))
# Out:
# Ali
# 28
# <class 'dict'>
